# %% [markdown]
# <a href="https://colab.research.google.com/github/Sovarna/Phyton-Assignement/blob/main/Phyton_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -O enron.db https://curtin-my.sharepoint.com/:u:/g/personal/211934g_curtin_edu_au/EaYagsqa2r1Bi5wtHbswGFwBH2kd2uTnz6rlka7GI36GUQ?download=1
# Out:
# --2023-05-24 08:57:18--  https://curtin-my.sharepoint.com/:u:/g/personal/211934g_curtin_edu_au/EaYagsqa2r1Bi5wtHbswGFwBH2kd2uTnz6rlka7GI36GUQ?download=1
# Resolving curtin-my.sharepoint.com (curtin-my.sharepoint.com)... 52.105.206.39, 2a01:111:f402:f043::39
# Connecting to curtin-my.sharepoint.com (curtin-my.sharepoint.com)|52.105.206.39|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /personal/211934g_curtin_edu_au/Documents/Teaching/ISYS2001/ISYS2001-Assignment-2-Data/enron_sqlite3.db?ga=1 [following]
# --2023-05-24 08:57:19--  https://curtin-my.sharepoint.com/personal/211934g_curtin_edu_au/Documents/Teaching/ISYS2001/ISYS2001-Assignment-2-Data/enron_sqlite3.db?ga=1
# Reusing existing connection to curtin-my.sharepoint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 853819392 (814M) [application/octet-stream]
# Saving to: ‘enron.db’
#
# enron.db            100%[===================>] 814.27M  20.2MB/s    in 45s
#
# ...

# %%
import sqlite3
import pandas as pd

# %%
connect = sqlite3.connect("enron.db")

# %%
cur = connect.cursor()

# %%
sql = """
SELECT name
FROM sqlite_master
WHERE type = 'table';
"""

cur.execute(sql)
cur.fetchall()
# Out:
# [('employeelist',), ('message',), ('recipientinfo',), ('referenceinfo',)]

# %%
table_df = pd.read_sql_query(sql,connect)
table_df
# Out:
#             name
# 0   employeelist
# 1        message
# 2  recipientinfo
# 3  referenceinfo

# %%
sql2 = """
PRAGMA table_info('employeelist');
"""
cur.execute(sql2)
cur.fetchall()
# Out:
# [(0, 'eid', 'INTEGER', 1, None, 1),
#  (1, 'firstName', 'VARCHAR(31)', 1, "''", 0),
#  (2, 'lastName', 'VARCHAR(31)', 1, "''", 0),
#  (3, 'Email_id', 'VARCHAR(31)', 1, "''", 0),
#  (4, 'Email2', 'VARCHAR(31)', 0, None, 0),
#  (5, 'Email3', 'VARCHAR(31)', 0, None, 0),
#  (6, 'EMail4', 'VARCHAR(31)', 0, None, 0),
#  (7, 'folder', 'VARCHAR(31)', 1, "''", 0),
#  (8, 'status', 'VARCHAR(50)', 0, None, 0)]

# %%
employee_df = pd.read_sql_query(sql2,connect)
employee_df
# Out:
#    cid       name         type  notnull dflt_value  pk
# 0    0        eid      INTEGER        1       None   1
# 1    1  firstName  VARCHAR(31)        1         ''   0
# 2    2   lastName  VARCHAR(31)        1         ''   0
# 3    3   Email_id  VARCHAR(31)        1         ''   0
# 4    4     Email2  VARCHAR(31)        0       None   0
# 5    5     Email3  VARCHAR(31)        0       None   0
# 6    6     EMail4  VARCHAR(31)        0       None   0
# 7    7     folder  VARCHAR(31)        1         ''   0
# 8    8     status  VARCHAR(50)        0       None   0

# %%
SQL = """
SELECT eid AS Employee_ID,firstName,lastName,Email_id AS Email, Email2 AS secondary_Email,Email3,Email4 From Employeelist
LIMIT 11;
"""

cur.execute(SQL)

# %%
employee_df = pd.read_sql_query(SQL,connect)
employee_df
# Out:
#     Employee_ID  firstName  lastName                      Email  \
# 0             1     Robert    Badeer    robert.badeer@enron.com
# 1             2      Kevin     Hyatt      kevin.hyatt@enron.com
# 2             3      Tracy  Geaccone   tracy.geaccone@enron.com
# 3             4        Teb     Lokey        teb.lokey@enron.com
# 4             5    Richard      Ring     richard.ring@enron.com
# 5             6       Mark    Taylor    mark.e.taylor@enron.com
# 6             7    Theresa     Staab    theresa.staab@enron.com
# 7             8      Susan   Pereira  susan.w.pereira@enron.com
# 8             9  Stephanie     Panus  stephanie.panus@enron.com
# 9            10    Phillip     Allen  phillip.k.ellen@enron.com
# 10           11       Mark     Whitt       mark.whitt@enron.com
#
#              secondary_Email                    Email3 EMail4
# 0          rbadeer@enron.com
# 1      kevin_hyatt@enron.com          khyatt@enron.com
# 2   tracy_geaconne@enron.com
# ...

# %%
sql3 = """
PRAGMA table_info('message');
"""
cur.execute(sql3)
cur.fetchall()
# Out:
# [(0, 'mid', 'INTEGER', 1, "'0'", 1),
#  (1, 'sender', 'VARCHAR(127)', 1, "''", 0),
#  (2, 'date', 'DATETIME', 0, None, 0),
#  (3, 'message_id', 'VARCHAR(127)', 0, None, 0),
#  (4, 'subject', 'TEXT', 0, None, 0),
#  (5, 'body', 'TEXT', 0, None, 0),
#  (6, 'folder', 'VARCHAR(127)', 1, "''", 0)]

# %%
message_df = pd.read_sql_query(sql3,connect)
message_df
# Out:
#    cid        name          type  notnull dflt_value  pk
# 0    0         mid       INTEGER        1        '0'   1
# 1    1      sender  VARCHAR(127)        1         ''   0
# 2    2        date      DATETIME        0       None   0
# 3    3  message_id  VARCHAR(127)        0       None   0
# 4    4     subject          TEXT        0       None   0
# 5    5        body          TEXT        0       None   0
# 6    6      folder  VARCHAR(127)        1         ''   0

# %%
SQL = """
SELECT mid AS message_ID, sender, date, message_id FROM message 
Limit 11;
"""

cur.execute(SQL)

# %%
message_df = pd.read_sql_query(SQL,connect)
message_df
# Out:
#     message_ID                         sender                 date  \
# 0           52        press.release@enron.com  2000-01-21 04:51:00
# 1           53      office.chairman@enron.com  2000-01-24 01:37:00
# 2           54      office.chairman@enron.com  2000-01-24 02:06:00
# 3           55        press.release@enron.com  2000-02-02 10:21:00
# 4           56      office.chairman@enron.com  2000-02-07 22:16:00
# 5           57               foothi19@idt.net  2000-08-25 02:09:00
# 6           58  enron.announcements@enron.com  2000-06-21 11:46:00
# 7           59   christopher.calger@enron.com  2000-06-27 08:58:00
# 8           60      christian.yoder@enron.com  2000-07-25 08:14:00
# 9           61        carla.hoffman@enron.com  2000-07-27 10:27:00
# 10          62          shari.stack@enron.com  2000-07-31 11:32:00
#
#                                        message_id
# 0   <12435833.1075863606729.JavaMail.evans@thyme>
# 1   <29664079.1075863606676.JavaMail.evans@thyme>
# ...

# %%
sql4 = """
PRAGMA table_info('Recipientinfo');
"""
cur.execute(sql4)
cur.fetchall()
# Out:
# [(0, 'rid', 'INTEGER', 1, "'0'", 1),
#  (1, 'mid', 'INTEGER', 1, "'0'", 0),
#  (2, 'rtype', 'TEXT', 0, None, 0),
#  (3, 'rvalue', 'VARCHAR(127)', 0, None, 0),
#  (4, 'dater', 'DATETIME', 0, None, 0)]

# %%
Recipientinfo_df = pd.read_sql_query(sql4,connect)
Recipientinfo_df
# Out:
#    cid    name          type  notnull dflt_value  pk
# 0    0     rid       INTEGER        1        '0'   1
# 1    1     mid       INTEGER        1        '0'   0
# 2    2   rtype          TEXT        0       None   0
# 3    3  rvalue  VARCHAR(127)        0       None   0
# 4    4   dater      DATETIME        0       None   0

# %%
SQL = """
SELECT rid As Reference_Id, mid, rtype, rvalue FROM Recipientinfo
limit 11;
"""

cur.execute(SQL)

# %%
Recipientinfo_df = pd.read_sql_query(SQL,connect)
Recipientinfo_df
# Out:
#     Reference_Id  mid rtype                             rvalue
# 0             67   52    TO            all.worldwide@enron.com
# 1             68   53    TO             all.downtown@enron.com
# 2             69   54    TO      all.enron-worldwide@enron.com
# 3             70   55    TO            all.worldwide@enron.com
# 4             71   56    TO  all_enron_north.america@enron.com
# 5             72   56    TO        ec.communications@enron.com
# 6             73   57    TO                 charlotte@wptf.org
# 7             74   58    TO              sap.mailout@enron.com
# 8             75   59    TO            robert.badeer@enron.com
# 9             76   60    TO               tim.belden@enron.com
# 10            77   60    TO            robert.badeer@enron.com

# %%
sql5 = """
PRAGMA table_info('Referenceinfo');
"""
cur.execute(sql5)
cur.fetchall()
# Out:
# [(0, 'rfid', 'INTEGER', 1, "'0'", 1),
#  (1, 'mid', 'INTEGER', 1, "'0'", 0),
#  (2, 'reference', 'TEXT', 0, None, 0)]

# %%
Referenceinfo_df = pd.read_sql_query(sql5,connect)
Referenceinfo_df
# Out:
#    cid       name     type  notnull dflt_value  pk
# 0    0       rfid  INTEGER        1        '0'   1
# 1    1        mid  INTEGER        1        '0'   0
# 2    2  reference     TEXT        0       None   0

# %%
SQL = """
SELECT rfid As Referenceinfo_ID, mid As Message_Id, reference FROM Referenceinfo
Limit 11;
"""

cur.execute(SQL)

# %%
Referenceinfo_df = pd.read_sql_query(SQL,connect)
Referenceinfo_df
# Out:
#     Referenceinfo_ID  Message_Id  \
# 0                  2          79
# 1                  3          99
# 2                  8         533
# 3                 13         842
# 4                 14         845
# 5                 15         846
# 6                 16         847
# 7                 17         848
# 8                 18         849
# 9                 19         851
# 10                20         852
#
#                                             reference
# 0   > From: Le Vine, Debi> Sent: Thursday, August ...
# 1   > From: Golden, Mark> Sent: Thursday, August 2...
# 2   From: Sole, JeanneSent: Friday, August 18, 200...
# 3   From: \tGrigsby, Mike  Sent:\tThursday, March ...
# 4   From: Monaco, John [EM] [mailto:john.monaco@ci...
# 5   From: \tRangel, Ina  Sent:\tThursday, March 07...
# 6   From: \tGrigsby, Mike  Sent:\tFriday, March 08...
# 7   From: \tGrigsby, Mike  Sent:\tFriday, March 08...
# 8   From: \tRangel, Ina  Sent:\tThursday, March 07...
# ...

# %% [markdown]
# ### EMAIL TRAFFIC OVER Time
# Count of volume send over time

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
SQL = """
SELECT date FROM message
"""
message_df = pd.read_sql_query(SQL,connect)
message_df
# Out:
#                        date
# 0       2000-01-21 04:51:00
# 1       2000-01-24 01:37:00
# 2       2000-01-24 02:06:00
# 3       2000-02-02 10:21:00
# 4       2000-02-07 22:16:00
# ...                     ...
# 252754  2002-02-06 16:51:29
# 252755  2002-02-06 17:17:39
# 252756  2002-02-06 20:09:37
# 252757  2002-02-07 04:38:13
# 252758  2002-02-07 05:38:14
#
# [252759 rows x 1 columns]

# %%
#count number of email per day using sql query

SQL = """

SELECT strftime('%Y-%M-%d',date)
AS date,
COUNT(*) AS count FROM message
GROUP BY date

"""
cur.execute(SQL)
# Converting the above code in a df
messageperday_df = pd.read_sql_query(SQL, connect)
messageperday_df
# Out:
#               date  count
# 0       0001-10-30      2
# 1       0001-40-18      1
# 2       0001-11-24      1
# 3       0001-30-01      1
# 4       0001-06-06      1
# ...            ...    ...
# 194082  2020-53-29      1
# 194083  2043-34-28      1
# 194084  2044-46-02      1
# 194085  2044-59-04      1
# 194086  2044-48-04      1
#
# [194087 rows x 2 columns]

# %%
fig = plt.subplots(figsize=(20,5))
sns.lineplot(x= 'date', y= 'count',data= messageperday_df)
# Out:
# <Axes: xlabel='date', ylabel='count'>

# %%
SQL = """

SELECT strftime('%Y-%M-%w', date)
AS date,
COUNT(*) AS count FROM message
GROUP BY date

"""
cur.execute(SQL)
# Converting the above code in a df
messageperweek_df = pd.read_sql_query(SQL, connect)
messageperweek_df
# Out:
#              date  count
# 0       0001-10-3      2
# 1       0001-40-1      1
# 2       0001-11-2      1
# 3       0001-30-3      1
# 4       0001-06-1      1
# ...           ...    ...
# 194082  2020-53-2      1
# 194083  2043-34-1      1
# 194084  2044-46-6      1
# 194085  2044-59-1      1
# 194086  2044-48-1      1
#
# [194087 rows x 2 columns]

# %%
fig = plt.subplots(figsize=(20,5))
sns.lineplot(x= 'date', y= 'count',data= messageperweek_df)
# Out:
# <Axes: xlabel='date', ylabel='count'>

# %%
SQL = """

SELECT strftime('%Y-%M', date)
AS date,
COUNT(*) AS count FROM message
GROUP BY date

"""
cur.execute(SQL)
# Converting the above code in a df
messagepermonth_df = pd.read_sql_query(SQL, connect)
messagepermonth_df
# Out:
#            date  count
# 0       0001-10      2
# 1       0001-40      1
# 2       0001-11      1
# 3       0001-30      1
# 4       0001-06      1
# ...         ...    ...
# 194082  2020-53      1
# 194083  2043-34      1
# 194084  2044-46      1
# 194085  2044-59      1
# 194086  2044-48      1
#
# [194087 rows x 2 columns]

# %%
fig = plt.subplots(figsize=(20,5))
sns.lineplot(x= 'date', y= 'count',data= messagepermonth_df)
# Out:
# <Axes: xlabel='date', ylabel='count'>

# %% [markdown]
# ### Top Senders and Recepients

# %% [markdown]
# # Top Sender

# %%
SQL = """

SELECT sender, mid As Num_emailId, COUNT(*) FROM message
GROUP BY sender
ORDER BY Num_emailId, COUNT(*) DESC
LIMIT 11;

"""
cur.execute(SQL)

# %%
F_Esenders_df = pd.read_sql(SQL,connect)
F_Esenders_df
# Out:
#                            sender  Num_emailId  COUNT(*)
# 0         press.release@enron.com           52        14
# 1       office.chairman@enron.com           53       284
# 2                foothi19@idt.net           57        18
# 3   enron.announcements@enron.com           58      2838
# 4    christopher.calger@enron.com           59       107
# 5       christian.yoder@enron.com           60       115
# 6         carla.hoffman@enron.com           61        67
# 7           shari.stack@enron.com           62       146
# 8          joseph.alamo@enron.com           64       226
# 9               bwoertz@caiso.com           65        35
# 10       heather.dunton@enron.com           66       124

# %% [markdown]
# ## Bar Chart for Top senders

# %%
fig = plt.subplots(figsize=(20,5))
sns.barplot(x= 'Num_emailId', y= 'sender',data= F_Esenders_df)
plt.title('Top Sender Email')
plt.show()

# %% [markdown]
# # Top Recipients

# %%
SQL = """

SELECT rvalue As Recipient_E, mid As Num_emailId, COUNT(*) FROM Recipientinfo
GROUP BY rvalue
ORDER BY Num_emailId, COUNT(*) DESC
Limit 11;

"""

cur.execute(SQL)

# %%
F_RecipientE_df = pd.read_sql(SQL,connect)
F_RecipientE_df
# Out:
#                           Recipient_E  Num_emailId  COUNT(*)
# 0             all.worldwide@enron.com           52      1144
# 1              all.downtown@enron.com           53       114
# 2       all.enron-worldwide@enron.com           54         6
# 3   all_enron_north.america@enron.com           56         6
# 4         ec.communications@enron.com           56         5
# 5                  charlotte@wptf.org           57        45
# 6               sap.mailout@enron.com           58        12
# 7             robert.badeer@enron.com           59      1756
# 8                tim.belden@enron.com           60      4819
# 9           elizabeth.sager@enron.com           60      4691
# 10             jeff.richter@enron.com           60      1819

# %% [markdown]
# ### Bar Chart for Recipients

# %%
fig = plt.subplots(figsize=(20,5))
sns.barplot(x= 'Num_emailId', y= 'Recipient_E',data= F_RecipientE_df)
plt.title('Top Recipient Email')
plt.show()

# %% [markdown]
# ## Email Distribution By Recipient Type

# %%
SQL = """

SELECT rtype, COUNT (*) AS Category FROM Recipientinfo
WHERE rtype IN ('to', 'cc','bcc')
GROUP BY rtype

"""
cur.execute(SQL)

# %%
rtype_valuedf = pd.read_sql(SQL,connect)
rtype_valuedf
# Out:
# Empty DataFrame
# Columns: [rtype, Category]
# Index: []
